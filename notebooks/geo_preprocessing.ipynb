# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
data = pd.read_csv("../data/raw/global_data_sustainable_energy.csv")
data.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
#    Financial flows to developing countries (US $)  \
# 0                                         20000.0
# 1                                        130000.0
# 2                                       3950000.0
# 3                                      25970000.0
# 4                                             NaN
#
#    Renewable energy share in the total final energy consumption (%)  \
# 0                                              44.99
# 1                                              45.60
# 2                                              37.83
# 3                                              36.66
# 4                                              44.24
#
#    Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                 0.16                             0.0
# 1                                 0.09                             0.0
# 2                                 0.13                             0.0
# 3                                 0.31                             0.0
# 4                                 0.33                             0.0
#
#    Electricity from renewables (TWh)  ...  \
# 0                               0.31  ...
# 1                               0.50  ...
# 2                               0.56  ...
# 3                               0.63  ...
# 4                               0.56  ...
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                          302.59482
# 1                                          236.89185
# 2                                          210.86215
# 3                                          229.96822
# 4                                          204.23125
#
#    Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 0                                               1.64
# 1                                               1.74
# 2                                               1.40
# 3                                               1.40
# 4                                               1.20
#
#    Value_co2_emissions_kt_by_country  \
# 0                         760.000000
# 1                         730.000000
# 2                        1029.999971
# 3                        1220.000029
# 4                        1029.999971
#
#    Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 0                                       NaN         NaN             NaN
# 1                                       NaN         NaN             NaN
# 2                                       NaN         NaN      179.426579
# 3                                       NaN    8.832278      190.683814
# 4                                       NaN    1.414118      211.382074
#
#    Density\n(P/Km2) Land Area(Km2)  Latitude  Longitude
# 0                60       652230.0  33.93911  67.709953
# 1                60       652230.0  33.93911  67.709953
# 2                60       652230.0  33.93911  67.709953
# 3                60       652230.0  33.93911  67.709953
# 4                60       652230.0  33.93911  67.709953
#
# [5 rows x 21 columns]

# %%
url = "https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip"
world_countries = gpd.read_file(url)
world_countries.head()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE TLC                        ADMIN  ...  \
# 0         0      2  Sovereign country   1                         Fiji  ...
# 1         0      2  Sovereign country   1  United Republic of Tanzania  ...
# 2         0      2      Indeterminate   1               Western Sahara  ...
# 3         0      2  Sovereign country   1                       Canada  ...
# 4         1      2            Country   1     United States of America  ...
#
#       FCLASS_TR     FCLASS_ID     FCLASS_PL FCLASS_GR  FCLASS_IT  \
# 0          None          None          None      None       None
# 1          None          None          None      None       None
# 2  Unrecognized  Unrecognized  Unrecognized      None       None
# 3          None          None          None      None       None
# 4          None          None          None      None       None
#
#       FCLASS_NL FCLASS_SE  FCLASS_BD FCLASS_UA  \
# 0          None      None       None      None
# 1          None      None       None      None
# 2  Unrecognized      None       None      None
# 3          None      None       None      None
# 4          None      None       None      None
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#
# [5 rows x 169 columns]

# %%
world_countries = world_countries[
    ["NAME", "CONTINENT",  'SUBREGION', "POP_EST", 'ECONOMY', 'INCOME_GRP', 'GDP_MD', 'geometry']
].rename(
    columns=lambda x: x.lower()  # Lowercase column names
).assign(
    gdp_per_capita=lambda x: x["gdp_md"] / x["pop_est"] * 1e6
).query(
    'continent != "Antarctica"'
)
world_countries.head()
# Out:
#                        name      continent         subregion      pop_est  \
# 0                      Fiji        Oceania         Melanesia     889953.0
# 1                  Tanzania         Africa    Eastern Africa   58005463.0
# 2                 W. Sahara         Africa   Northern Africa     603253.0
# 3                    Canada  North America  Northern America   37589262.0
# 4  United States of America  North America  Northern America  328239523.0
#
#                      economy              income_grp    gdp_md  \
# 0       6. Developing region  4. Lower middle income      5496
# 1  7. Least developed region           5. Low income     63177
# 2  7. Least developed region           5. Low income       907
# 3    1. Developed region: G7    1. High income: OECD   1736425
# 4    1. Developed region: G7    1. High income: OECD  21433226
#
#                                             geometry  gdp_per_capita
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...     6175.607026
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...     1089.156033
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...     1503.515109
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...    46194.708478
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...    65297.517508

# %%
name_mapping = {
    'United States of America': 'United States',
    'S. Sudan': 'South Sudan',
    'Bosnia and Herz.': 'Bosnia and Herzegovina',
    'Central African Rep.': 'Central African Republic',
    'Dominican Rep.': 'Dominican Republic',
    'Eq. Guinea': 'Equatorial Guinea',
    'eSwatini': 'Eswatini',
    'Solomon Is.': 'Solomon Islands'
}

# Replace values in the DataFrame
world_countries['name'] = world_countries['name'].replace(name_mapping)

# %%
merged_df = pd.merge(data, world_countries, how='left', left_on='Entity', right_on='name')
merged_df.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
#    Financial flows to developing countries (US $)  \
# 0                                         20000.0
# 1                                        130000.0
# 2                                       3950000.0
# 3                                      25970000.0
# 4                                             NaN
#
#    Renewable energy share in the total final energy consumption (%)  \
# 0                                              44.99
# 1                                              45.60
# 2                                              37.83
# 3                                              36.66
# 4                                              44.24
#
#    Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                 0.16                             0.0
# 1                                 0.09                             0.0
# 2                                 0.13                             0.0
# 3                                 0.31                             0.0
# 4                                 0.33                             0.0
#
#    Electricity from renewables (TWh)  ...  Longitude         name  continent  \
# 0                               0.31  ...  67.709953  Afghanistan       Asia
# 1                               0.50  ...  67.709953  Afghanistan       Asia
# 2                               0.56  ...  67.709953  Afghanistan       Asia
# 3                               0.63  ...  67.709953  Afghanistan       Asia
# 4                               0.56  ...  67.709953  Afghanistan       Asia
#
#        subregion     pop_est                    economy     income_grp  \
# 0  Southern Asia  38041754.0  7. Least developed region  5. Low income
# 1  Southern Asia  38041754.0  7. Least developed region  5. Low income
# 2  Southern Asia  38041754.0  7. Least developed region  5. Low income
# 3  Southern Asia  38041754.0  7. Least developed region  5. Low income
# 4  Southern Asia  38041754.0  7. Least developed region  5. Low income
#
#     gdp_md                                           geometry  \
# 0  19291.0  POLYGON ((66.51861 37.36278, 67.07578 37.35614...
# 1  19291.0  POLYGON ((66.51861 37.36278, 67.07578 37.35614...
# 2  19291.0  POLYGON ((66.51861 37.36278, 67.07578 37.35614...
# 3  19291.0  POLYGON ((66.51861 37.36278, 67.07578 37.35614...
# 4  19291.0  POLYGON ((66.51861 37.36278, 67.07578 37.35614...
#
#    gdp_per_capita_y
# 0        507.100698
# 1        507.100698
# 2        507.100698
# 3        507.100698
# 4        507.100698
#
# [5 rows x 30 columns]

# %%
unmatched_entities = merged_df[merged_df['name'].isnull()]
unmatched_entities.Entity.unique()
# Out:
# array(['Antigua and Barbuda', 'Aruba', 'Bahrain', 'Barbados', 'Bermuda',
#        'Cayman Islands', 'Comoros', 'Dominica', 'French Guiana',
#        'Grenada', 'Kiribati', 'Maldives', 'Malta', 'Mauritius', 'Nauru',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa',
#        'Sao Tome and Principe', 'Seychelles', 'Singapore', 'Tonga',
#        'Tuvalu'], dtype=object)

# %%
important_cols = [
    'Entity',
    'Year',
    'Renewable energy share in the total final energy consumption (%)',
    'Access to electricity (% of population)',
    'Financial flows to developing countries (US $)',
    'Electricity from nuclear (TWh)',
    'Electricity from renewables (TWh)',
    'Electricity from fossil fuels (TWh)',
    'continent',
    'subregion',
    'pop_est', 
    'economy',
    'income_grp', 
    'gdp_md', 
    'geometry', 
    'gdp_per_capita_y'
]

preprocessed_df = merged_df[important_cols]
preprocessed_df.head()
# Out:
#         Entity  Year  \
# 0  Afghanistan  2000
# 1  Afghanistan  2001
# 2  Afghanistan  2002
# 3  Afghanistan  2003
# 4  Afghanistan  2004
#
#    Renewable energy share in the total final energy consumption (%)  \
# 0                                              44.99
# 1                                              45.60
# 2                                              37.83
# 3                                              36.66
# 4                                              44.24
#
#    Access to electricity (% of population)  \
# 0                                 1.613591
# 1                                 4.074574
# 2                                 9.409158
# 3                                14.738506
# 4                                20.064968
#
#    Financial flows to developing countries (US $)  \
# 0                                         20000.0
# 1                                        130000.0
# 2                                       3950000.0
# 3                                      25970000.0
# 4                                             NaN
#
#    Electricity from nuclear (TWh)  Electricity from renewables (TWh)  \
# 0                             0.0                               0.31
# 1                             0.0                               0.50
# 2                             0.0                               0.56
# 3                             0.0                               0.63
# 4                             0.0                               0.56
#
#    Electricity from fossil fuels (TWh) continent      subregion     pop_est  \
# 0                                 0.16      Asia  Southern Asia  38041754.0
# 1                                 0.09      Asia  Southern Asia  38041754.0
# 2                                 0.13      Asia  Southern Asia  38041754.0
# 3                                 0.31      Asia  Southern Asia  38041754.0
# 4                                 0.33      Asia  Southern Asia  38041754.0
#
#                      economy     income_grp   gdp_md  \
# 0  7. Least developed region  5. Low income  19291.0
# 1  7. Least developed region  5. Low income  19291.0
# 2  7. Least developed region  5. Low income  19291.0
# 3  7. Least developed region  5. Low income  19291.0
# 4  7. Least developed region  5. Low income  19291.0
#
#                                             geometry  gdp_per_capita_y
# 0  POLYGON ((66.51861 37.36278, 67.07578 37.35614...        507.100698
# 1  POLYGON ((66.51861 37.36278, 67.07578 37.35614...        507.100698
# 2  POLYGON ((66.51861 37.36278, 67.07578 37.35614...        507.100698
# 3  POLYGON ((66.51861 37.36278, 67.07578 37.35614...        507.100698
# 4  POLYGON ((66.51861 37.36278, 67.07578 37.35614...        507.100698

# %%
preprocessed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Data columns (total 16 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            3649 non-null   object
#  1   Year                                                              3649 non-null   int64
#  2   Renewable energy share in the total final energy consumption (%)  3455 non-null   float64
#  3   Access to electricity (% of population)                           3639 non-null   float64
#  4   Financial flows to developing countries (US $)                    1560 non-null   float64
#  5   Electricity from nuclear (TWh)                                    3523 non-null   float64
#  6   Electricity from renewables (TWh)                                 3628 non-null   float64
#  7   Electricity from fossil fuels (TWh)                               3628 non-null   float64
#  8   continent                                                         3165 non-null   object
#  9   subregion                                                         3165 non-null   object
#  10  pop_est                                                           3165 non-null   float64
#  11  economy                                                           3165 non-null   object
#  12  income_grp                                                        3165 non-null   object
#  13  gdp_md                                                            3165 non-null   float64
#  14  geometry                                                          3165 non-null   geometry
#  15  gdp_per_capita_y                                                  3165 non-null   float64
# dtypes: float64(9), geometry(1), int64(1), object(5)
# memory usage: 456.3+ KB

# %%
population_df = preprocessed_df[['Entity', 'pop_est']].copy()
population_df['pop_est'] = population_df['pop_est'].apply(lambda x: str(round(x)) if not pd.isnull(x) else np.nan)
population_df['pop_est'] = population_df['pop_est'].fillna('Not Available')
population_df = population_df.groupby("Entity")["pop_est"].first().reset_index()
population_df['pop_est'] = population_df['pop_est'].astype(str)
population_df
# Out:
#                   Entity        pop_est
# 0            Afghanistan       38041754
# 1                Albania        2854191
# 2                Algeria       43053054
# 3                 Angola       31825295
# 4    Antigua and Barbuda  Not Available
# ..                   ...            ...
# 171           Uzbekistan       33580650
# 172              Vanuatu         299882
# 173                Yemen       29161922
# 174               Zambia       17861030
# 175             Zimbabwe       14645468
#
# [176 rows x 2 columns]

# %%
population_df.to_parquet("../data/preprocessed/population_df.parquet")

# %%
preprocessed_gdf = gpd.GeoDataFrame(preprocessed_df)
preprocessed_gdf = preprocessed_gdf[preprocessed_gdf['Entity'] != 'French Guiana']

# %%
preprocessed_gdf.to_parquet("../data/preprocessed/preprocessed_gdf.parquet")
world_countries.to_parquet("../data/preprocessed/world_countries.parquet")
