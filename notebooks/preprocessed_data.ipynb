# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import altair as alt

# %%
data = pd.read_csv("../data/raw/global_data_sustainable_energy.csv")

filtered_data = data[data['Year'].between(2016, 2020)]

grouped_data = filtered_data.groupby('Entity').mean(numeric_only=True).reset_index()

grouped_data.drop(columns='Year', inplace=True)

grouped_data.head()
# Out:
#                 Entity  Access to electricity (% of population)  \
# 0          Afghanistan                                97.483227
# 1              Albania                                99.956000
# 2              Algeria                                99.597542
# 3               Angola                                44.529960
# 4  Antigua and Barbuda                               100.000000
#
#    Access to clean fuels for cooking  \
# 0                              30.86
# 1                              79.66
# 2                              99.64
# 3                              49.00
# 4                             100.00
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                              9.628
# 1                                                NaN
# 2                                             15.144
# 3                                             93.842
# 4                                             83.512
#
#    Financial flows to developing countries (US $)  \
# 0                                      31477500.0
# 1                                             NaN
# 2                                         70000.0
# 3                                      31380000.0
# 4                                      19550000.0
#
#    Renewable energy share in the total final energy consumption (%)  \
# 0                                            18.9000
# 1                                                NaN
# 2                                             0.1425
# 3                                            54.3325
# 4                                             0.7525
#
#    Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                0.166                             0.0
# 1                                0.000                             0.0
# 2                               71.294                             0.0
# 3                                3.798                             0.0
# 4                                0.320                             0.0
#
#    Electricity from renewables (TWh)  Low-carbon electricity (% electricity)  \
# 0                              0.938                               84.902724
# 1                              6.226                              100.000000
# 2                              0.664                                0.914286
# 3                              9.344                               70.504888
# 4                              0.010                                3.012478
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                         824.370898
# 1                                       12795.873400
# 2                                       15524.617400
# 3                                        3518.684920
# 4                                       32032.284200
#
#    Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 0                                             2.3475
# 1                                             2.6100
# 2                                             5.0725
# 3                                             2.7525
# 4                                             3.6500
#
#    Value_co2_emissions_kt_by_country  \
# 0                        5557.500124
# 1                        4889.999986
# 2                      162509.998325
# 3                       25794.999598
# 4                         507.499993
#
#    Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 0                                       NaN    1.531410      505.057656
# 1                                       NaN    1.858918     4916.938059
# 2                                   0.25463    0.300000     3898.939141
# 3                                       NaN   -2.151105     3095.464027
# 4                                       NaN    0.038858    15726.261038
#
#    Land Area(Km2)   Latitude  Longitude
# 0        652230.0  33.939110  67.709953
# 1         28748.0  41.153332  20.168331
# 2       2381741.0  28.033886   1.659626
# 3       1246700.0 -11.202692  17.873887
# 4           443.0  17.060816 -61.796428

# %%
grouped_data.to_csv('../data/preprocessed/processed_data.csv', index=False)
